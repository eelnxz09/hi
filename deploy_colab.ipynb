# %% [markdown]
# # 🛡️ Banking Fraud Detection System - Deployment
#
# This notebook deploys the fraud detection system with a public URL.
#
# **Steps:**
# 1. Clone repository from GitHub
# 2. Install dependencies
# 3. Train model
# 4. Deploy with ngrok
# 5. Get public URL

# %%
# STEP 1: Clone Repository
# !git clone https://github.com/YOUR_USERNAME/fraud-detection-system.git
# %cd fraud-detection-system
# !ls -la

# %%
# STEP 2: Install Dependencies
# !pip install -q -r requirements.txt
print("✅ Dependencies installed!")

# %%
# STEP 3: Train Model
# !python train_model.py

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def home():
    return "Fraud Detection System is Running"

app.run(host="0.0.0.0", port=5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.28.0.12:5000
# INFO:werkzeug:Press CTRL+C to quit

# %%
# !pip install pyngrok

# %%
# STEP 4: Setup ngrok
from pyngrok import ngrok
import threading
import time

# Get FREE token from: https://dashboard.ngrok.com/get-started/your-authtoken
# Uncomment and add your token:
ngrok.set_auth_token("39IfYh9iQDxVHGUIRuniP8gi4Ic_7HTVnszeq41eMcpTRjwQ8")

# Start ngrok tunnel
public_url = ngrok.connect(5000)

print('\n' + '='*70)
print('🌐 PUBLIC URL:', public_url)
print('='*70)
print('✅ Your Fraud Detection System is LIVE!')
print('📱 Share this URL with anyone to access the system')
print('='*70 + '\n')

# %%
# STEP 5: Run Flask App
# NOTE: This cell will keep running. Don't stop it!
# !python app.py
